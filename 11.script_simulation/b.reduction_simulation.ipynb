# %%
import pandas as pd
import numpy as np

# Load abundance data
nafld_abd = pd.read_csv('../data/NAFLD/abd.tsv', sep='\t', index_col=0)
metadata = pd.read_csv('../data/NAFLD/NASH_forward_63_map.txt', sep='\t')
metadata.columns = [col.replace('#', '') for col in metadata.columns]
nash_samples = metadata[metadata['DiseaseStatus'] == 'NASH']['SampleID'].tolist()
nash_abundance = nafld_abd.loc[:, nafld_abd.columns.isin(nash_samples)]

# Filter tax
threshold = 0.8
sample_count = nash_abundance.shape[1]
min_samples = int(sample_count * threshold)
present_in_most = (nash_abundance > 0).sum(axis=1) >= min_samples
nash_abundance_filtered = nash_abundance.loc[present_in_most]
nash_abundance_filtered.index = nash_abundance_filtered.index.str.replace('s__', '')
output_filename = f'nash_abundance_filtered_threshold_{int(threshold*100)}.tsv'
nash_abundance_filtered.to_csv(output_filename, sep='\t')

# Print summary
print(f"Total samples: {len(metadata)}")
print(f"NASH samples: {len(nash_samples)}")
print(f"Original species: {len(nash_abundance.index)}")
print(f"Filtered species: {len(nash_abundance_filtered.index)}")
print(f"Species present in at least {threshold*100}% of samples: {len(nash_abundance_filtered.index)}")

# Calculate filtered percentage
filtered_ratio = (len(nash_abundance.index) - len(nash_abundance_filtered.index)) / len(nash_abundance.index) * 100
print(f"Percentage of species filtered: {filtered_ratio:.2f}%")
# Out:
# Total samples: 63
# NASH samples: 22
# Original species: 97
# Filtered species: 33
# Species present in at least 80.0% of samples: 33
# Percentage of species filtered: 65.98%

# %% [markdown]
# ## Make causal inference network [optional]
# Those steps follow the NAFLD cohort(10.1002/imt2.61) provided scripts https://github.com/tjcadd2020/NAFLD_keystone/blob/master/NAFLD_Discovery_20190916_Final.ipynb to get the causal network.
#
#
# ### 1. SparCC
# We recommand install in a new conda enviroment for python confilct.
#
# ```conda create --name sparcc python=2.7```
#
# ```conda active sparcc```
#
# ```pip install numpy==1.10.1```
#
# ```pip install pandas```
#
# Download yonatanf-sparcc-3aff6141c3f1.zip from https://github.com/tjcadd2020/NAFLD_keystone/tree/master/pkg and unzip
# Make sure the scipt is in ```yonatanf-sparcc-3aff6141c3f1/``` not ```yonatanf-sparcc-3aff6141c3f1/yonatanf-sparcc-3aff6141c3f1/```
#
# ```python run_sparcc.py```
#
# input
# - nash_abundance_filtered_threshold_80.tsv
# output
# - NASH_F_corr_threshold_80.tsv
# - NASH_F_p_threshold_80_one_sided.tsv
#
# ### 2.Causal inference
# ```conda create --name dowhy python=3.6```
#
# ```conda active dowhy```
#
# ```conda install conda-forge::dowhy```
#
# ```python run_causalinference.py```
# output
# - cancer_causal_threshold_80/
# - threshold_80_NASH_F_causal_p_one_sided.tsv
# - threshold_80_NASH_F_causal.tsv

# %%
# Load causal inference

A = pd.read_csv('cancer_causal_threshold_80/cancer_ematrix_2.csv', index_col=0, sep=',')
prior = pd.read_csv('cancer_causal_threshold_80/cancer_pmatrix_2.csv', index_col=0, sep=',')
A *= (prior>=0.9)

# %%
import numpy as np
import pandas as pd
import random

def prepare_sample_for_perturbation(abundance_file, sample_idx=0):
    """
    Prepare a single sample's relative abundance for perturbation analysis
    
    Args:
        abundance_file: str, TSV file path
        sample_idx: int, index of sample to select (default 0)
    
    Returns:
        sample: Series, processed sample relative abundance
    """

    abundance_df = pd.read_csv(abundance_file, sep='\t', index_col=0)
    
    sample = abundance_df.iloc[:, sample_idx]
    
    if np.abs(sample.sum() - 1.0) > 0.01: 
        sample = sample / sample.sum()
    
    sample = sample.clip(lower=0)
    
    return sample

def get_delta_X(A, inventions, abundances, decay=0.5, max_iter=100):
    """Calculate abundance changes after network propagation"""
    for it in range(max_iter):
        inventions += np.round(np.dot(A, inventions) * abundances * decay**(it), 5)
    return inventions

def allocate_reduction(species_list, total_reduction, sample, OTUs):
    """
    Allocate reduction amount to selected species
    
    Args:
        species_list: list, species to reduce
        total_reduction: float, total amount to reduce
        sample: Series, original abundances
        OTUs: list, all OTUs
    
    Returns:
        inventions: array, intervention vector
    """
    inventions = np.zeros(len(OTUs))
    n_species = len(species_list)
    
    if n_species == 1:
        idx = OTUs.index(species_list[0])
        inventions[idx] = -total_reduction
    else:
        split_points = np.random.uniform(0, total_reduction, n_species-1)
        split_points = np.sort(split_points)
        
        reductions = np.diff(np.concatenate(([0], split_points, [total_reduction])))
        
        for otu, red in zip(species_list, reductions):
            idx = OTUs.index(otu)
            inventions[idx] = -red
            
    return inventions

def simulate_relative_abundance_perturbation(sample, A_matrix, total_reduction=0.05, 
                                           primary_candidate_otus=None, secondary_candidate_otus=None,
                                           decay=0.5, max_iter=100, random_seed=42):
    """
    Simulate random perturbation of relative abundance
    
    Uses primary candidates first, then secondary candidates if needed
    """
    random.seed(random_seed)
    np.random.seed(random_seed)
    
    OTUs = list(A_matrix.columns)
    original_sum = sample.sum()
    reduction_amount = original_sum * total_reduction
    
    primary_valid = []
    secondary_valid = []
    
    if primary_candidate_otus is None and secondary_candidate_otus is None:
        candidate_otus = OTUs
        n_species_to_reduce = max(1, int(len(candidate_otus) * np.random.uniform(0.2, 0.8)))
        selection_probs = sample / sample.sum()
        try:
            perturb_otus = list(np.random.choice(
                candidate_otus,
                size=min(n_species_to_reduce, len(candidate_otus)),
                replace=False,
                p=selection_probs
            ))
            inventions = allocate_reduction(perturb_otus, reduction_amount, sample, OTUs)
        except ValueError:
            perturb_otus = [sample.idxmax()]
            inventions = np.zeros(len(OTUs))
            inventions[OTUs.index(perturb_otus[0])] = -reduction_amount
    else:
        if primary_candidate_otus is not None:
            primary_valid = [otu for otu in primary_candidate_otus if otu in OTUs]
        
        if secondary_candidate_otus is not None:
            secondary_valid = [otu for otu in secondary_candidate_otus if otu in OTUs]
        
        if primary_valid:
            primary_sample = sample[primary_valid]
            primary_total = primary_sample.sum()
            
            if primary_total >= reduction_amount:
                n_primary_to_reduce = max(1, int(len(primary_valid) * np.random.uniform(0.2, 0.8)))
                selection_probs = primary_sample / primary_sample.sum()
                try:
                    perturb_otus = list(np.random.choice(
                        primary_valid,
                        size=min(n_primary_to_reduce, len(primary_valid)),
                        replace=False,
                        p=selection_probs
                    ))
                    inventions = allocate_reduction(perturb_otus, reduction_amount, sample, OTUs)
                except ValueError:
                    perturb_otus = [primary_sample.idxmax()]
                    inventions = np.zeros(len(OTUs))
                    inventions[OTUs.index(perturb_otus[0])] = -reduction_amount
            else:
                perturb_otus = primary_valid.copy()
                inventions = np.zeros(len(OTUs))
                
                for otu in primary_valid:
                    idx = OTUs.index(otu)
                    inventions[idx] = -sample[otu]
                
                remaining_reduction = reduction_amount - primary_total
                
                if secondary_valid:
                    secondary_sample = sample[secondary_valid]
                    n_secondary_to_reduce = max(1, int(len(secondary_valid) * np.random.uniform(0.2, 0.8)))
                    selection_probs = secondary_sample / secondary_sample.sum()
                    
                    try:
                        additional_otus = list(np.random.choice(
                            secondary_valid,
                            size=min(n_secondary_to_reduce, len(secondary_valid)),
                            replace=False,
                            p=selection_probs
                        ))
                        perturb_otus.extend(additional_otus)
                        
                        secondary_inventions = allocate_reduction(additional_otus, remaining_reduction, sample, OTUs)
                        inventions += secondary_inventions
                        
                    except ValueError:
                        max_otu = secondary_sample.idxmax()
                        perturb_otus.append(max_otu)
                        inventions[OTUs.index(max_otu)] = -remaining_reduction
        
        elif secondary_valid: 
            secondary_sample = sample[secondary_valid]
            n_secondary_to_reduce = max(1, int(len(secondary_valid) * np.random.uniform(0.2, 0.8)))
            selection_probs = secondary_sample / secondary_sample.sum()
            
            try:
                perturb_otus = list(np.random.choice(
                    secondary_valid,
                    size=min(n_secondary_to_reduce, len(secondary_valid)),
                    replace=False,
                    p=selection_probs
                ))
                inventions = allocate_reduction(perturb_otus, reduction_amount, sample, OTUs)
            except ValueError:
                perturb_otus = [secondary_sample.idxmax()]
                inventions = np.zeros(len(OTUs))
                inventions[OTUs.index(perturb_otus[0])] = -reduction_amount
                
    # Calculate network propagation effects
    delta_abundance = get_delta_X(A_matrix, inventions, sample, decay, max_iter)
    
    # Calculate final abundance
    final_abundance = sample + delta_abundance
    
    # Ensure non-negative abundance
    final_abundance = np.maximum(final_abundance, 0)
    return pd.Series(final_abundance, index=OTUs), perturb_otus, inventions

def calculate_FR(abundances, distance_file="../data/NAFLD/NASH_distance.tsv"):
    """
    Calculate Functional Redundancy (FR)
    FR = sum(dij * pi * pj) where i ≠ j
    
    Args:
        abundances: Series, species abundances
        distance_file: str, path to species distance matrix
    """
    distances = pd.read_csv(distance_file, sep='\t', index_col=0)
    
    distances.index = distances.index.str.replace('s__', '')
    distances.columns = distances.columns.str.replace('s__', '')
    
    common_species = sorted(set(abundances.index) & set(distances.index))
    
    if not common_species:
        raise ValueError("No common species found between abundance data and distance matrix")
    
    abundances = abundances[common_species]
    distances = distances.loc[common_species, common_species]
    
    fr = 0
    n = len(common_species)
    
    for i in range(n):
        for j in range(n):
            if i != j:
                species_i = common_species[i]
                species_j = common_species[j]
                fr += distances.iloc[i, j] * abundances[species_i] * abundances[species_j]
    
    return fr

# %%
sample = prepare_sample_for_perturbation('nash_abundance_filtered_threshold_80.tsv')
keystone_species = ['B. caecicola-OTU4']
keystone_cluster = ['B. caecicola-OTU4','F. prausnitzii-OTU80','B. producta-OTU32','F. prausnitzii-OTU8','Ezakiella-OTU94','A. ruminis-OTU75','C. pinnipediorum','B. coprophilus','Escherichia-Shigella-OTU88','F. magna','P. buccalis','A. octavius','B. barnesiae','P. sp. 2007b','P. ivorii','D. pneumosintes','P. loveana','P. olsenii','E. peruensis','P. lacrimalis','S5-A14a-OTU76']
other_species = [sp for sp in sample.index if sp not in keystone_cluster]

# %%
# Load file to get sample count
df = pd.read_csv('nash_abundance_filtered_threshold_80.tsv', sep='\t')
n_samples = df.shape[1] 

# Set random seed
seed = 42
np.random.seed(seed)

# 生成100次模拟的参数
n_simulations = 100
simulation_params = pd.DataFrame({
    'simulation_id': range(n_simulations),
    'sample_idx': np.random.randint(0, n_samples-1, size=n_simulations), 
    'random_seed': np.random.randint(0, 1000, size=n_simulations)
})

# Save parameters to file
output_filename = f'simulation_params_root_seed_{seed}.tsv'
simulation_params.to_csv(output_filename, sep='\t', index=False)

print("Simulation parameters preview:")
print(simulation_params.head(10))
print("\nParameter statistics:")
print(f"Total sample count: {n_samples}")
print(f"Sample index range: {simulation_params['sample_idx'].min()}-{simulation_params['sample_idx'].max()}")
print(f"Random seed range: {simulation_params['random_seed'].min()}-{simulation_params['random_seed'].max()}")
print(f"\nParameters saved to file: {output_filename}")
# Out:
# Simulation parameters preview:
#    simulation_id  sample_idx  random_seed
# 0              0           6          378
# 1              1          19          772
# 2              2          14          489
# 3              3          10          230
# 4              4           7           40
# 5              5          20           27
# 6              6           6          134
# 7              7          18          200
# 8              8          10          839
# 9              9          10          779
#
# Parameter statistics:
# Total sample count: 23
# Sample index range: 0-21
# Random seed range: 4-986
#
# Parameters saved to file: simulation_params_root_seed_42.tsv

# %%
def run_simulation_with_reduction(seed, total_reduction):
    # Load simulation parameters
    params_df = pd.read_csv(f'simulation_params_root_seed_{seed}.tsv', sep='\t')
    params_df['random_seed'] = params_df['random_seed'].astype(int)

    columns = ['simulation_id', 'sample_idx', 'random_seed', 
              'total_reduction',  # 新增total_reduction列
              'original_FR',
              'keystone_species_FR', 'keystone_cluster_FR', 
              'random_FR', 'other_species_FR']
    results_df = pd.DataFrame(columns=columns)

    # Run 100 simulations
    for _, row in params_df.iterrows():
        sim_id = int(row['simulation_id'])
        sample_idx = int(row['sample_idx'])
        sim_seed = int(row['random_seed'])
        
        print(f"Running simulation {sim_id}, sample_idx={sample_idx}, seed={sim_seed}, reduction={total_reduction}")
        
        sample = prepare_sample_for_perturbation('nash_abundance_filtered_threshold_80.tsv', 
                                               sample_idx=sample_idx)
        
        original_FR = calculate_FR(sample)
        
         # 1. Keystone species perturbation
        result_keystone = simulate_relative_abundance_perturbation(
            sample, A,
            primary_candidate_otus=keystone_species,
            secondary_candidate_otus=keystone_cluster,
            total_reduction=total_reduction,  
            random_seed=sim_seed
        )
        keystone_FR = calculate_FR(result_keystone[0])
        
        # 2. Keystone cluster perturbation
        result_cluster = simulate_relative_abundance_perturbation(
            sample, A,
            primary_candidate_otus=keystone_cluster,
            secondary_candidate_otus=other_species,
            total_reduction=total_reduction,  
            random_seed=sim_seed
        )
        cluster_FR = calculate_FR(result_cluster[0])
        
        # 3. Random perturbation
        result_random = simulate_relative_abundance_perturbation(
            sample, A,
            total_reduction=total_reduction, 
            random_seed=sim_seed
        )
        random_FR = calculate_FR(result_random[0])
        
        # 4. Other species perturbation
        result_other = simulate_relative_abundance_perturbation(
            sample, A,
            primary_candidate_otus=other_species,
            secondary_candidate_otus=keystone_cluster,
            total_reduction=total_reduction,  
            random_seed=sim_seed
        )
        other_FR = calculate_FR(result_other[0])
        
        
        results_df.loc[len(results_df)] = [
            sim_id, sample_idx, sim_seed,
            total_reduction, 
            original_FR,
            keystone_FR, cluster_FR,
            random_FR, other_FR
        ]
        
        if (sim_id + 1) % 10 == 0:
            print(f"Completed {sim_id + 1} simulations")

    # Save results
    output_filename = f'simulation_results_root_seed_{seed}_reduction_{total_reduction}.tsv'
    results_df.to_csv(output_filename, sep='\t', index=False)

    print(f"\nAll simulations completed, results saved to: {output_filename}")
    print("\nResults preview:")
    print(results_df.head())

    print("\nBasic statistics:")
    for col in results_df.columns[4:]: 
        print(f"\n{col}:")
        print(results_df[col].describe())
    
    return results_df

seed = 42

# Different reduction values
reductions = [0.05, 0.1, 0.15, 0.2] 
all_results = {}

for reduction in reductions:
    print(f"\nRunning simulations with total_reduction = {reduction}")
    all_results[reduction] = run_simulation_with_reduction(seed, reduction)
# Out:
# Running simulations with total_reduction = 0.05
# Running simulation 0, sample_idx=6, seed=378, reduction=0.05
# Running simulation 1, sample_idx=19, seed=772, reduction=0.05
# Running simulation 2, sample_idx=14, seed=489, reduction=0.05
# Running simulation 3, sample_idx=10, seed=230, reduction=0.05
# Running simulation 4, sample_idx=7, seed=40, reduction=0.05
# Running simulation 5, sample_idx=20, seed=27, reduction=0.05
# Running simulation 6, sample_idx=6, seed=134, reduction=0.05
# Running simulation 7, sample_idx=18, seed=200, reduction=0.05
# Running simulation 8, sample_idx=10, seed=839, reduction=0.05
# Running simulation 9, sample_idx=10, seed=779, reduction=0.05
# Completed 10 simulations
# Running simulation 10, sample_idx=20, seed=929, reduction=0.05
# Running simulation 11, sample_idx=3, seed=32, reduction=0.05
# Running simulation 12, sample_idx=7, seed=47, reduction=0.05
# Running simulation 13, sample_idx=2, seed=502, reduction=0.05
# Running simulation 14, sample_idx=21, seed=406, reduction=0.05
# Running simulation 15, sample_idx=20, seed=573, reduction=0.05
# Running simulation 16, sample_idx=1, seed=727, reduction=0.05
# Running simulation 17, sample_idx=11, seed=804, reduction=0.05
# Running simulation 18, sample_idx=5, seed=98, reduction=0.05
# Running simulation 19, sample_idx=1, seed=683, reduction=0.05
# Completed 20 simulations
# Running simulation 20, sample_idx=20, seed=871, reduction=0.05
# Running simulation 21, sample_idx=0, seed=725, reduction=0.05
# Running simulation 22, sample_idx=11, seed=986, reduction=0.05
# Running simulation 23, sample_idx=21, seed=546, reduction=0.05
# Running simulation 24, sample_idx=11, seed=960, reduction=0.05
# Running simulation 25, sample_idx=16, seed=738, reduction=0.05
# Running simulation 26, sample_idx=9, seed=612, reduction=0.05
# Running simulation 27, sample_idx=15, seed=942, reduction=0.05
# Running simulation 28, sample_idx=14, seed=461, reduction=0.05
# Running simulation 29, sample_idx=14, seed=642, reduction=0.05
# Completed 30 simulations
# Running simulation 30, sample_idx=18, seed=768, reduction=0.05
# Running simulation 31, sample_idx=11, seed=4, reduction=0.05
# Running simulation 32, sample_idx=19, seed=217, reduction=0.05
# Running simulation 33, sample_idx=2, seed=502, reduction=0.05
# Running simulation 34, sample_idx=4, seed=766, reduction=0.05
# Running simulation 35, sample_idx=18, seed=397, reduction=0.05
# Running simulation 36, sample_idx=6, seed=870, reduction=0.05
# Running simulation 37, sample_idx=20, seed=794, reduction=0.05
# Running simulation 38, sample_idx=8, seed=392, reduction=0.05
# Running simulation 39, sample_idx=6, seed=206, reduction=0.05
# Completed 40 simulations
# Running simulation 40, sample_idx=17, seed=14, reduction=0.05
# Running simulation 41, sample_idx=3, seed=857, reduction=0.05
# Running simulation 42, sample_idx=13, seed=553, reduction=0.05
# Running simulation 43, sample_idx=17, seed=891, reduction=0.05
# Running simulation 44, sample_idx=8, seed=460, reduction=0.05
# Running simulation 45, sample_idx=20, seed=690, reduction=0.05
# Running simulation 46, sample_idx=1, seed=574, reduction=0.05
# Running simulation 47, sample_idx=19, seed=863, reduction=0.05
# Running simulation 48, sample_idx=14, seed=742, reduction=0.05
# Running simulation 49, sample_idx=6, seed=240, reduction=0.05
# Completed 50 simulations
# Running simulation 50, sample_idx=11, seed=563, reduction=0.05
# Running simulation 51, sample_idx=7, seed=95, reduction=0.05
# Running simulation 52, sample_idx=14, seed=899, reduction=0.05
# Running simulation 53, sample_idx=2, seed=733, reduction=0.05
# Running simulation 54, sample_idx=13, seed=484, reduction=0.05
# Running simulation 55, sample_idx=16, seed=406, reduction=0.05
# Running simulation 56, sample_idx=3, seed=230, reduction=0.05
# Running simulation 57, sample_idx=17, seed=748, reduction=0.05
# Running simulation 58, sample_idx=7, seed=654, reduction=0.05
# Running simulation 59, sample_idx=3, seed=170, reduction=0.05
# Completed 60 simulations
# Running simulation 60, sample_idx=1, seed=540, reduction=0.05
# Running simulation 61, sample_idx=5, seed=35, reduction=0.05
# Running simulation 62, sample_idx=21, seed=524, reduction=0.05
# Running simulation 63, sample_idx=9, seed=159, reduction=0.05
# Running simulation 64, sample_idx=3, seed=838, reduction=0.05
# Running simulation 65, sample_idx=21, seed=698, reduction=0.05
# Running simulation 66, sample_idx=17, seed=242, reduction=0.05
# Running simulation 67, sample_idx=11, seed=85, reduction=0.05
# Running simulation 68, sample_idx=1, seed=795, reduction=0.05
# Running simulation 69, sample_idx=9, seed=577, reduction=0.05
# Completed 70 simulations
# Running simulation 70, sample_idx=3, seed=681, reduction=0.05
# Running simulation 71, sample_idx=13, seed=556, reduction=0.05
# Running simulation 72, sample_idx=15, seed=573, reduction=0.05
# Running simulation 73, sample_idx=14, seed=952, reduction=0.05
# Running simulation 74, sample_idx=7, seed=645, reduction=0.05
# Running simulation 75, sample_idx=13, seed=795, reduction=0.05
# Running simulation 76, sample_idx=7, seed=27, reduction=0.05
# Running simulation 77, sample_idx=20, seed=619, reduction=0.05
# Running simulation 78, sample_idx=15, seed=555, reduction=0.05
# Running simulation 79, sample_idx=12, seed=339, reduction=0.05
# Completed 80 simulations
# Running simulation 80, sample_idx=17, seed=797, reduction=0.05
# Running simulation 81, sample_idx=14, seed=957, reduction=0.05
# Running simulation 82, sample_idx=20, seed=330, reduction=0.05
# Running simulation 83, sample_idx=12, seed=639, reduction=0.05
# Running simulation 84, sample_idx=8, seed=505, reduction=0.05
# Running simulation 85, sample_idx=14, seed=347, reduction=0.05
# Running simulation 86, sample_idx=12, seed=472, reduction=0.05
# Running simulation 87, sample_idx=0, seed=230, reduction=0.05
# Running simulation 88, sample_idx=6, seed=189, reduction=0.05
# Running simulation 89, sample_idx=8, seed=224, reduction=0.05
# Completed 90 simulations
# Running simulation 90, sample_idx=0, seed=384, reduction=0.05
# Running simulation 91, sample_idx=11, seed=376, reduction=0.05
# Running simulation 92, sample_idx=7, seed=282, reduction=0.05
# Running simulation 93, sample_idx=10, seed=957, reduction=0.05
# Running simulation 94, sample_idx=18, seed=632, reduction=0.05
# Running simulation 95, sample_idx=16, seed=627, reduction=0.05
# Running simulation 96, sample_idx=7, seed=972, reduction=0.05
# Running simulation 97, sample_idx=2, seed=744, reduction=0.05
# Running simulation 98, sample_idx=2, seed=258, reduction=0.05
# Running simulation 99, sample_idx=0, seed=358, reduction=0.05
# Completed 100 simulations
#
# All simulations completed, results saved to: simulation_results_root_seed_42_reduction_0.05.tsv
#
# Results preview:
#    simulation_id  sample_idx  random_seed  total_reduction  original_FR  \
# 0            0.0         6.0        378.0             0.05     0.439145
# 1            1.0        19.0        772.0             0.05     0.260981
# 2            2.0        14.0        489.0             0.05     0.504654
# 3            3.0        10.0        230.0             0.05     0.460912
# 4            4.0         7.0         40.0             0.05     0.560738
#
#    keystone_species_FR  keystone_cluster_FR  random_FR  other_species_FR
# 0             0.370110             0.384202   0.390848          0.412837
# 1             0.221874             0.219863   0.210246          0.237605
# 2             0.437643             0.449330   0.451657          0.457587
# 3             0.392179             0.404388   0.412184          0.415003
# 4             0.492832             0.490357   0.498016          0.516162
#
# Basic statistics:
#
# original_FR:
# count    100.000000
# mean       0.452626
# std        0.082612
# min        0.260981
# 25%        0.409907
# 50%        0.439145
# 75%        0.506998
# max        0.571662
# Name: original_FR, dtype: float64
#
# keystone_species_FR:
# count    100.000000
# mean       0.385652
# std        0.077267
# min        0.218626
# 25%        0.343569
# 50%        0.372044
# 75%        0.437643
# max        0.499041
# Name: keystone_species_FR, dtype: float64
#
# keystone_cluster_FR:
# count    100.000000
# mean       0.395820
# std        0.076525
# min        0.206447
# 25%        0.354603
# 50%        0.387047
# 75%        0.451350
# max        0.511077
# Name: keystone_cluster_FR, dtype: float64
#
# random_FR:
# count    100.000000
# mean       0.400797
# std        0.077546
# min        0.210246
# 25%        0.360470
# 50%        0.391880
# 75%        0.461649
# max        0.524940
# Name: random_FR, dtype: float64
#
# other_species_FR:
# count    100.000000
# mean       0.412171
# std        0.076237
# min        0.225651
# 25%        0.367948
# 50%        0.410232
# 75%        0.473110
# max        0.530875
# Name: other_species_FR, dtype: float64
#
# Running simulations with total_reduction = 0.1
# Running simulation 0, sample_idx=6, seed=378, reduction=0.1
# Running simulation 1, sample_idx=19, seed=772, reduction=0.1
# Running simulation 2, sample_idx=14, seed=489, reduction=0.1
# Running simulation 3, sample_idx=10, seed=230, reduction=0.1
# Running simulation 4, sample_idx=7, seed=40, reduction=0.1
# Running simulation 5, sample_idx=20, seed=27, reduction=0.1
# Running simulation 6, sample_idx=6, seed=134, reduction=0.1
# Running simulation 7, sample_idx=18, seed=200, reduction=0.1
# Running simulation 8, sample_idx=10, seed=839, reduction=0.1
# Running simulation 9, sample_idx=10, seed=779, reduction=0.1
# Completed 10 simulations
# Running simulation 10, sample_idx=20, seed=929, reduction=0.1
# Running simulation 11, sample_idx=3, seed=32, reduction=0.1
# Running simulation 12, sample_idx=7, seed=47, reduction=0.1
# Running simulation 13, sample_idx=2, seed=502, reduction=0.1
# Running simulation 14, sample_idx=21, seed=406, reduction=0.1
# Running simulation 15, sample_idx=20, seed=573, reduction=0.1
# Running simulation 16, sample_idx=1, seed=727, reduction=0.1
# Running simulation 17, sample_idx=11, seed=804, reduction=0.1
# Running simulation 18, sample_idx=5, seed=98, reduction=0.1
# Running simulation 19, sample_idx=1, seed=683, reduction=0.1
# Completed 20 simulations
# Running simulation 20, sample_idx=20, seed=871, reduction=0.1
# Running simulation 21, sample_idx=0, seed=725, reduction=0.1
# Running simulation 22, sample_idx=11, seed=986, reduction=0.1
# Running simulation 23, sample_idx=21, seed=546, reduction=0.1
# Running simulation 24, sample_idx=11, seed=960, reduction=0.1
# Running simulation 25, sample_idx=16, seed=738, reduction=0.1
# Running simulation 26, sample_idx=9, seed=612, reduction=0.1
# Running simulation 27, sample_idx=15, seed=942, reduction=0.1
# Running simulation 28, sample_idx=14, seed=461, reduction=0.1
# Running simulation 29, sample_idx=14, seed=642, reduction=0.1
# Completed 30 simulations
# Running simulation 30, sample_idx=18, seed=768, reduction=0.1
# Running simulation 31, sample_idx=11, seed=4, reduction=0.1
# Running simulation 32, sample_idx=19, seed=217, reduction=0.1
# Running simulation 33, sample_idx=2, seed=502, reduction=0.1
# Running simulation 34, sample_idx=4, seed=766, reduction=0.1
# Running simulation 35, sample_idx=18, seed=397, reduction=0.1
# Running simulation 36, sample_idx=6, seed=870, reduction=0.1
# Running simulation 37, sample_idx=20, seed=794, reduction=0.1
# Running simulation 38, sample_idx=8, seed=392, reduction=0.1
# Running simulation 39, sample_idx=6, seed=206, reduction=0.1
# Completed 40 simulations
# Running simulation 40, sample_idx=17, seed=14, reduction=0.1
# Running simulation 41, sample_idx=3, seed=857, reduction=0.1
# Running simulation 42, sample_idx=13, seed=553, reduction=0.1
# Running simulation 43, sample_idx=17, seed=891, reduction=0.1
# Running simulation 44, sample_idx=8, seed=460, reduction=0.1
# Running simulation 45, sample_idx=20, seed=690, reduction=0.1
# Running simulation 46, sample_idx=1, seed=574, reduction=0.1
# Running simulation 47, sample_idx=19, seed=863, reduction=0.1
# Running simulation 48, sample_idx=14, seed=742, reduction=0.1
# Running simulation 49, sample_idx=6, seed=240, reduction=0.1
# Completed 50 simulations
# Running simulation 50, sample_idx=11, seed=563, reduction=0.1
# Running simulation 51, sample_idx=7, seed=95, reduction=0.1
# Running simulation 52, sample_idx=14, seed=899, reduction=0.1
# Running simulation 53, sample_idx=2, seed=733, reduction=0.1
# Running simulation 54, sample_idx=13, seed=484, reduction=0.1
# Running simulation 55, sample_idx=16, seed=406, reduction=0.1
# Running simulation 56, sample_idx=3, seed=230, reduction=0.1
# Running simulation 57, sample_idx=17, seed=748, reduction=0.1
# Running simulation 58, sample_idx=7, seed=654, reduction=0.1
# Running simulation 59, sample_idx=3, seed=170, reduction=0.1
# Completed 60 simulations
# Running simulation 60, sample_idx=1, seed=540, reduction=0.1
# Running simulation 61, sample_idx=5, seed=35, reduction=0.1
# Running simulation 62, sample_idx=21, seed=524, reduction=0.1
# Running simulation 63, sample_idx=9, seed=159, reduction=0.1
# Running simulation 64, sample_idx=3, seed=838, reduction=0.1
# Running simulation 65, sample_idx=21, seed=698, reduction=0.1
# Running simulation 66, sample_idx=17, seed=242, reduction=0.1
# Running simulation 67, sample_idx=11, seed=85, reduction=0.1
# Running simulation 68, sample_idx=1, seed=795, reduction=0.1
# Running simulation 69, sample_idx=9, seed=577, reduction=0.1
# Completed 70 simulations
# Running simulation 70, sample_idx=3, seed=681, reduction=0.1
# Running simulation 71, sample_idx=13, seed=556, reduction=0.1
# Running simulation 72, sample_idx=15, seed=573, reduction=0.1
# Running simulation 73, sample_idx=14, seed=952, reduction=0.1
# Running simulation 74, sample_idx=7, seed=645, reduction=0.1
# Running simulation 75, sample_idx=13, seed=795, reduction=0.1
# Running simulation 76, sample_idx=7, seed=27, reduction=0.1
# Running simulation 77, sample_idx=20, seed=619, reduction=0.1
# Running simulation 78, sample_idx=15, seed=555, reduction=0.1
# Running simulation 79, sample_idx=12, seed=339, reduction=0.1
# Completed 80 simulations
# Running simulation 80, sample_idx=17, seed=797, reduction=0.1
# Running simulation 81, sample_idx=14, seed=957, reduction=0.1
# Running simulation 82, sample_idx=20, seed=330, reduction=0.1
# Running simulation 83, sample_idx=12, seed=639, reduction=0.1
# Running simulation 84, sample_idx=8, seed=505, reduction=0.1
# Running simulation 85, sample_idx=14, seed=347, reduction=0.1
# Running simulation 86, sample_idx=12, seed=472, reduction=0.1
# Running simulation 87, sample_idx=0, seed=230, reduction=0.1
# Running simulation 88, sample_idx=6, seed=189, reduction=0.1
# Running simulation 89, sample_idx=8, seed=224, reduction=0.1
# Completed 90 simulations
# Running simulation 90, sample_idx=0, seed=384, reduction=0.1
# Running simulation 91, sample_idx=11, seed=376, reduction=0.1
# Running simulation 92, sample_idx=7, seed=282, reduction=0.1
# Running simulation 93, sample_idx=10, seed=957, reduction=0.1
# Running simulation 94, sample_idx=18, seed=632, reduction=0.1
# Running simulation 95, sample_idx=16, seed=627, reduction=0.1
# Running simulation 96, sample_idx=7, seed=972, reduction=0.1
# Running simulation 97, sample_idx=2, seed=744, reduction=0.1
# Running simulation 98, sample_idx=2, seed=258, reduction=0.1
# Running simulation 99, sample_idx=0, seed=358, reduction=0.1
# Completed 100 simulations
#
# All simulations completed, results saved to: simulation_results_root_seed_42_reduction_0.1.tsv
#
# Results preview:
#    simulation_id  sample_idx  random_seed  total_reduction  original_FR  \
# 0            0.0         6.0        378.0              0.1     0.439145
# 1            1.0        19.0        772.0              0.1     0.260981
# 2            2.0        14.0        489.0              0.1     0.504654
# 3            3.0        10.0        230.0              0.1     0.460912
# 4            4.0         7.0         40.0              0.1     0.560738
#
#    keystone_species_FR  keystone_cluster_FR  random_FR  other_species_FR
# 0             0.301069             0.346642   0.355323          0.345253
# 1             0.187688             0.186034   0.168681          0.230261
# 2             0.394633             0.412899   0.410867          0.428400
# 3             0.323445             0.355546   0.376994          0.386672
# 4             0.424877             0.423242   0.449076          0.497990
#
# Basic statistics:
#
# original_FR:
# count    100.000000
# mean       0.452626
# std        0.082612
# min        0.260981
# 25%        0.409907
# 50%        0.439145
# 75%        0.506998
# max        0.571662
# Name: original_FR, dtype: float64
#
# keystone_species_FR:
# count    100.000000
# mean       0.325067
# std        0.077144
# min        0.168883
# 25%        0.273701
# 50%        0.310782
# 75%        0.395970
# max        0.428212
# Name: keystone_species_FR, dtype: float64
#
# keystone_cluster_FR:
# count    100.000000
# mean       0.349941
# std        0.071315
# min        0.151647
# 25%        0.312820
# 50%        0.351921
# 75%        0.400394
# max        0.456907
# Name: keystone_cluster_FR, dtype: float64
#
# random_FR:
# count    100.000000
# mean       0.360168
# std        0.073518
# min        0.168681
# 25%        0.321633
# 50%        0.358145
# 75%        0.411146
# max        0.491432
# Name: random_FR, dtype: float64
#
# other_species_FR:
# count    100.000000
# mean       0.373360
# std        0.074944
# min        0.188394
# 25%        0.331955
# 50%        0.384562
# 75%        0.421527
# max        0.519230
# Name: other_species_FR, dtype: float64
#
# Running simulations with total_reduction = 0.15
# Running simulation 0, sample_idx=6, seed=378, reduction=0.15
# Running simulation 1, sample_idx=19, seed=772, reduction=0.15
# Running simulation 2, sample_idx=14, seed=489, reduction=0.15
# Running simulation 3, sample_idx=10, seed=230, reduction=0.15
# Running simulation 4, sample_idx=7, seed=40, reduction=0.15
# Running simulation 5, sample_idx=20, seed=27, reduction=0.15
# Running simulation 6, sample_idx=6, seed=134, reduction=0.15
# Running simulation 7, sample_idx=18, seed=200, reduction=0.15
# Running simulation 8, sample_idx=10, seed=839, reduction=0.15
# Running simulation 9, sample_idx=10, seed=779, reduction=0.15
# Completed 10 simulations
# Running simulation 10, sample_idx=20, seed=929, reduction=0.15
# Running simulation 11, sample_idx=3, seed=32, reduction=0.15
# Running simulation 12, sample_idx=7, seed=47, reduction=0.15
# Running simulation 13, sample_idx=2, seed=502, reduction=0.15
# Running simulation 14, sample_idx=21, seed=406, reduction=0.15
# Running simulation 15, sample_idx=20, seed=573, reduction=0.15
# Running simulation 16, sample_idx=1, seed=727, reduction=0.15
# Running simulation 17, sample_idx=11, seed=804, reduction=0.15
# Running simulation 18, sample_idx=5, seed=98, reduction=0.15
# Running simulation 19, sample_idx=1, seed=683, reduction=0.15
# Completed 20 simulations
# Running simulation 20, sample_idx=20, seed=871, reduction=0.15
# Running simulation 21, sample_idx=0, seed=725, reduction=0.15
# Running simulation 22, sample_idx=11, seed=986, reduction=0.15
# Running simulation 23, sample_idx=21, seed=546, reduction=0.15
# Running simulation 24, sample_idx=11, seed=960, reduction=0.15
# Running simulation 25, sample_idx=16, seed=738, reduction=0.15
# Running simulation 26, sample_idx=9, seed=612, reduction=0.15
# Running simulation 27, sample_idx=15, seed=942, reduction=0.15
# Running simulation 28, sample_idx=14, seed=461, reduction=0.15
# Running simulation 29, sample_idx=14, seed=642, reduction=0.15
# Completed 30 simulations
# Running simulation 30, sample_idx=18, seed=768, reduction=0.15
# Running simulation 31, sample_idx=11, seed=4, reduction=0.15
# Running simulation 32, sample_idx=19, seed=217, reduction=0.15
# Running simulation 33, sample_idx=2, seed=502, reduction=0.15
# Running simulation 34, sample_idx=4, seed=766, reduction=0.15
# Running simulation 35, sample_idx=18, seed=397, reduction=0.15
# Running simulation 36, sample_idx=6, seed=870, reduction=0.15
# Running simulation 37, sample_idx=20, seed=794, reduction=0.15
# Running simulation 38, sample_idx=8, seed=392, reduction=0.15
# Running simulation 39, sample_idx=6, seed=206, reduction=0.15
# Completed 40 simulations
# Running simulation 40, sample_idx=17, seed=14, reduction=0.15
# Running simulation 41, sample_idx=3, seed=857, reduction=0.15
# Running simulation 42, sample_idx=13, seed=553, reduction=0.15
# Running simulation 43, sample_idx=17, seed=891, reduction=0.15
# Running simulation 44, sample_idx=8, seed=460, reduction=0.15
# Running simulation 45, sample_idx=20, seed=690, reduction=0.15
# Running simulation 46, sample_idx=1, seed=574, reduction=0.15
# Running simulation 47, sample_idx=19, seed=863, reduction=0.15
# Running simulation 48, sample_idx=14, seed=742, reduction=0.15
# Running simulation 49, sample_idx=6, seed=240, reduction=0.15
# Completed 50 simulations
# Running simulation 50, sample_idx=11, seed=563, reduction=0.15
# Running simulation 51, sample_idx=7, seed=95, reduction=0.15
# Running simulation 52, sample_idx=14, seed=899, reduction=0.15
# Running simulation 53, sample_idx=2, seed=733, reduction=0.15
# Running simulation 54, sample_idx=13, seed=484, reduction=0.15
# Running simulation 55, sample_idx=16, seed=406, reduction=0.15
# Running simulation 56, sample_idx=3, seed=230, reduction=0.15
# Running simulation 57, sample_idx=17, seed=748, reduction=0.15
# Running simulation 58, sample_idx=7, seed=654, reduction=0.15
# Running simulation 59, sample_idx=3, seed=170, reduction=0.15
# Completed 60 simulations
# Running simulation 60, sample_idx=1, seed=540, reduction=0.15
# Running simulation 61, sample_idx=5, seed=35, reduction=0.15
# Running simulation 62, sample_idx=21, seed=524, reduction=0.15
# Running simulation 63, sample_idx=9, seed=159, reduction=0.15
# Running simulation 64, sample_idx=3, seed=838, reduction=0.15
# Running simulation 65, sample_idx=21, seed=698, reduction=0.15
# Running simulation 66, sample_idx=17, seed=242, reduction=0.15
# Running simulation 67, sample_idx=11, seed=85, reduction=0.15
# Running simulation 68, sample_idx=1, seed=795, reduction=0.15
# Running simulation 69, sample_idx=9, seed=577, reduction=0.15
# Completed 70 simulations
# Running simulation 70, sample_idx=3, seed=681, reduction=0.15
# Running simulation 71, sample_idx=13, seed=556, reduction=0.15
# Running simulation 72, sample_idx=15, seed=573, reduction=0.15
# Running simulation 73, sample_idx=14, seed=952, reduction=0.15
# Running simulation 74, sample_idx=7, seed=645, reduction=0.15
# Running simulation 75, sample_idx=13, seed=795, reduction=0.15
# Running simulation 76, sample_idx=7, seed=27, reduction=0.15
# Running simulation 77, sample_idx=20, seed=619, reduction=0.15
# Running simulation 78, sample_idx=15, seed=555, reduction=0.15
# Running simulation 79, sample_idx=12, seed=339, reduction=0.15
# Completed 80 simulations
# Running simulation 80, sample_idx=17, seed=797, reduction=0.15
# Running simulation 81, sample_idx=14, seed=957, reduction=0.15
# Running simulation 82, sample_idx=20, seed=330, reduction=0.15
# Running simulation 83, sample_idx=12, seed=639, reduction=0.15
# Running simulation 84, sample_idx=8, seed=505, reduction=0.15
# Running simulation 85, sample_idx=14, seed=347, reduction=0.15
# Running simulation 86, sample_idx=12, seed=472, reduction=0.15
# Running simulation 87, sample_idx=0, seed=230, reduction=0.15
# Running simulation 88, sample_idx=6, seed=189, reduction=0.15
# Running simulation 89, sample_idx=8, seed=224, reduction=0.15
# Completed 90 simulations
# Running simulation 90, sample_idx=0, seed=384, reduction=0.15
# Running simulation 91, sample_idx=11, seed=376, reduction=0.15
# Running simulation 92, sample_idx=7, seed=282, reduction=0.15
# Running simulation 93, sample_idx=10, seed=957, reduction=0.15
# Running simulation 94, sample_idx=18, seed=632, reduction=0.15
# Running simulation 95, sample_idx=16, seed=627, reduction=0.15
# Running simulation 96, sample_idx=7, seed=972, reduction=0.15
# Running simulation 97, sample_idx=2, seed=744, reduction=0.15
# Running simulation 98, sample_idx=2, seed=258, reduction=0.15
# Running simulation 99, sample_idx=0, seed=358, reduction=0.15
# Completed 100 simulations
#
# All simulations completed, results saved to: simulation_results_root_seed_42_reduction_0.15.tsv
#
# Results preview:
#    simulation_id  sample_idx  random_seed  total_reduction  original_FR  \
# 0            0.0         6.0        378.0             0.15     0.439145
# 1            1.0        19.0        772.0             0.15     0.260981
# 2            2.0        14.0        489.0             0.15     0.504654
# 3            3.0        10.0        230.0             0.15     0.460912
# 4            4.0         7.0         40.0             0.15     0.560738
#
#    keystone_species_FR  keystone_cluster_FR  random_FR  other_species_FR
# 0             0.232028             0.310511   0.324745          0.302275
# 1             0.158178             0.156582   0.136737          0.149667
# 2             0.359608             0.386377   0.373764          0.406313
# 3             0.254712             0.314567   0.346001          0.375223
# 4             0.392209             0.360547   0.416308          0.396122
#
# Basic statistics:
#
# original_FR:
# count    100.000000
# mean       0.452626
# std        0.082612
# min        0.260981
# 25%        0.409907
# 50%        0.439145
# 75%        0.506998
# max        0.571662
# Name: original_FR, dtype: float64
#
# keystone_species_FR:
# count    100.000000
# mean       0.271465
# std        0.086076
# min        0.118823
# 25%        0.203808
# 50%        0.254591
# 75%        0.352380
# max        0.392209
# Name: keystone_species_FR, dtype: float64
#
# keystone_cluster_FR:
# count    100.000000
# mean       0.310528
# std        0.070474
# min        0.102033
# 25%        0.270310
# 50%        0.321206
# 75%        0.352916
# max        0.442006
# Name: keystone_cluster_FR, dtype: float64
#
# random_FR:
# count    100.000000
# mean       0.326890
# std        0.070063
# min        0.136737
# 25%        0.289649
# 50%        0.329747
# 75%        0.373791
# max        0.462994
# Name: random_FR, dtype: float64
#
# other_species_FR:
# count    100.000000
# mean       0.320581
# std        0.073032
# min        0.136737
# 25%        0.274590
# 50%        0.322936
# 75%        0.383617
# max        0.462082
# Name: other_species_FR, dtype: float64
#
# Running simulations with total_reduction = 0.2
# Running simulation 0, sample_idx=6, seed=378, reduction=0.2
# Running simulation 1, sample_idx=19, seed=772, reduction=0.2
# Running simulation 2, sample_idx=14, seed=489, reduction=0.2
# Running simulation 3, sample_idx=10, seed=230, reduction=0.2
# Running simulation 4, sample_idx=7, seed=40, reduction=0.2
# Running simulation 5, sample_idx=20, seed=27, reduction=0.2
# Running simulation 6, sample_idx=6, seed=134, reduction=0.2
# Running simulation 7, sample_idx=18, seed=200, reduction=0.2
# Running simulation 8, sample_idx=10, seed=839, reduction=0.2
# Running simulation 9, sample_idx=10, seed=779, reduction=0.2
# Completed 10 simulations
# Running simulation 10, sample_idx=20, seed=929, reduction=0.2
# Running simulation 11, sample_idx=3, seed=32, reduction=0.2
# Running simulation 12, sample_idx=7, seed=47, reduction=0.2
# Running simulation 13, sample_idx=2, seed=502, reduction=0.2
# Running simulation 14, sample_idx=21, seed=406, reduction=0.2
# Running simulation 15, sample_idx=20, seed=573, reduction=0.2
# Running simulation 16, sample_idx=1, seed=727, reduction=0.2
# Running simulation 17, sample_idx=11, seed=804, reduction=0.2
# Running simulation 18, sample_idx=5, seed=98, reduction=0.2
# Running simulation 19, sample_idx=1, seed=683, reduction=0.2
# Completed 20 simulations
# Running simulation 20, sample_idx=20, seed=871, reduction=0.2
# Running simulation 21, sample_idx=0, seed=725, reduction=0.2
# Running simulation 22, sample_idx=11, seed=986, reduction=0.2
# Running simulation 23, sample_idx=21, seed=546, reduction=0.2
# Running simulation 24, sample_idx=11, seed=960, reduction=0.2
# Running simulation 25, sample_idx=16, seed=738, reduction=0.2
# Running simulation 26, sample_idx=9, seed=612, reduction=0.2
# Running simulation 27, sample_idx=15, seed=942, reduction=0.2
# Running simulation 28, sample_idx=14, seed=461, reduction=0.2
# Running simulation 29, sample_idx=14, seed=642, reduction=0.2
# Completed 30 simulations
# Running simulation 30, sample_idx=18, seed=768, reduction=0.2
# Running simulation 31, sample_idx=11, seed=4, reduction=0.2
# Running simulation 32, sample_idx=19, seed=217, reduction=0.2
# Running simulation 33, sample_idx=2, seed=502, reduction=0.2
# Running simulation 34, sample_idx=4, seed=766, reduction=0.2
# Running simulation 35, sample_idx=18, seed=397, reduction=0.2
# Running simulation 36, sample_idx=6, seed=870, reduction=0.2
# Running simulation 37, sample_idx=20, seed=794, reduction=0.2
# Running simulation 38, sample_idx=8, seed=392, reduction=0.2
# Running simulation 39, sample_idx=6, seed=206, reduction=0.2
# Completed 40 simulations
# Running simulation 40, sample_idx=17, seed=14, reduction=0.2
# Running simulation 41, sample_idx=3, seed=857, reduction=0.2
# Running simulation 42, sample_idx=13, seed=553, reduction=0.2
# Running simulation 43, sample_idx=17, seed=891, reduction=0.2
# Running simulation 44, sample_idx=8, seed=460, reduction=0.2
# Running simulation 45, sample_idx=20, seed=690, reduction=0.2
# Running simulation 46, sample_idx=1, seed=574, reduction=0.2
# Running simulation 47, sample_idx=19, seed=863, reduction=0.2
# Running simulation 48, sample_idx=14, seed=742, reduction=0.2
# Running simulation 49, sample_idx=6, seed=240, reduction=0.2
# Completed 50 simulations
# Running simulation 50, sample_idx=11, seed=563, reduction=0.2
# Running simulation 51, sample_idx=7, seed=95, reduction=0.2
# Running simulation 52, sample_idx=14, seed=899, reduction=0.2
# Running simulation 53, sample_idx=2, seed=733, reduction=0.2
# Running simulation 54, sample_idx=13, seed=484, reduction=0.2
# Running simulation 55, sample_idx=16, seed=406, reduction=0.2
# Running simulation 56, sample_idx=3, seed=230, reduction=0.2
# Running simulation 57, sample_idx=17, seed=748, reduction=0.2
# Running simulation 58, sample_idx=7, seed=654, reduction=0.2
# Running simulation 59, sample_idx=3, seed=170, reduction=0.2
# Completed 60 simulations
# Running simulation 60, sample_idx=1, seed=540, reduction=0.2
# Running simulation 61, sample_idx=5, seed=35, reduction=0.2
# Running simulation 62, sample_idx=21, seed=524, reduction=0.2
# Running simulation 63, sample_idx=9, seed=159, reduction=0.2
# Running simulation 64, sample_idx=3, seed=838, reduction=0.2
# Running simulation 65, sample_idx=21, seed=698, reduction=0.2
# Running simulation 66, sample_idx=17, seed=242, reduction=0.2
# Running simulation 67, sample_idx=11, seed=85, reduction=0.2
# Running simulation 68, sample_idx=1, seed=795, reduction=0.2
# Running simulation 69, sample_idx=9, seed=577, reduction=0.2
# Completed 70 simulations
# Running simulation 70, sample_idx=3, seed=681, reduction=0.2
# Running simulation 71, sample_idx=13, seed=556, reduction=0.2
# Running simulation 72, sample_idx=15, seed=573, reduction=0.2
# Running simulation 73, sample_idx=14, seed=952, reduction=0.2
# Running simulation 74, sample_idx=7, seed=645, reduction=0.2
# Running simulation 75, sample_idx=13, seed=795, reduction=0.2
# Running simulation 76, sample_idx=7, seed=27, reduction=0.2
# Running simulation 77, sample_idx=20, seed=619, reduction=0.2
# Running simulation 78, sample_idx=15, seed=555, reduction=0.2
# Running simulation 79, sample_idx=12, seed=339, reduction=0.2
# Completed 80 simulations
# Running simulation 80, sample_idx=17, seed=797, reduction=0.2
# Running simulation 81, sample_idx=14, seed=957, reduction=0.2
# Running simulation 82, sample_idx=20, seed=330, reduction=0.2
# Running simulation 83, sample_idx=12, seed=639, reduction=0.2
# Running simulation 84, sample_idx=8, seed=505, reduction=0.2
# Running simulation 85, sample_idx=14, seed=347, reduction=0.2
# Running simulation 86, sample_idx=12, seed=472, reduction=0.2
# Running simulation 87, sample_idx=0, seed=230, reduction=0.2
# Running simulation 88, sample_idx=6, seed=189, reduction=0.2
# Running simulation 89, sample_idx=8, seed=224, reduction=0.2
# Completed 90 simulations
# Running simulation 90, sample_idx=0, seed=384, reduction=0.2
# Running simulation 91, sample_idx=11, seed=376, reduction=0.2
# Running simulation 92, sample_idx=7, seed=282, reduction=0.2
# Running simulation 93, sample_idx=10, seed=957, reduction=0.2
# Running simulation 94, sample_idx=18, seed=632, reduction=0.2
# Running simulation 95, sample_idx=16, seed=627, reduction=0.2
# Running simulation 96, sample_idx=7, seed=972, reduction=0.2
# Running simulation 97, sample_idx=2, seed=744, reduction=0.2
# Running simulation 98, sample_idx=2, seed=258, reduction=0.2
# Running simulation 99, sample_idx=0, seed=358, reduction=0.2
# Completed 100 simulations
#
# All simulations completed, results saved to: simulation_results_root_seed_42_reduction_0.2.tsv
#
# Results preview:
#    simulation_id  sample_idx  random_seed  total_reduction  original_FR  \
# 0            0.0         6.0        378.0              0.2     0.439145
# 1            1.0        19.0        772.0              0.2     0.260981
# 2            2.0        14.0        489.0              0.2     0.504654
# 3            3.0        10.0        230.0              0.2     0.460912
# 4            4.0         7.0         40.0              0.2     0.560738
#
#    keystone_species_FR  keystone_cluster_FR  random_FR  other_species_FR
# 0             0.162968             0.275826   0.298709          0.268739
# 1             0.129198             0.127618   0.106796          0.122524
# 2             0.337895             0.360710   0.343007          0.298011
# 3             0.229433             0.275850   0.326067          0.368560
# 4             0.360916             0.303455   0.397700          0.337460
#
# Basic statistics:
#
# original_FR:
# count    100.000000
# mean       0.452626
# std        0.082612
# min        0.260981
# 25%        0.409907
# 50%        0.439145
# 75%        0.506998
# max        0.571662
# Name: original_FR, dtype: float64
#
# keystone_species_FR:
# count    100.000000
# mean       0.224947
# std        0.098641
# min        0.068771
# 25%        0.133941
# 50%        0.229433
# 75%        0.314691
# max        0.375875
# Name: keystone_species_FR, dtype: float64
#
# keystone_cluster_FR:
# count    100.000000
# mean       0.277095
# std        0.071809
# min        0.073984
# 25%        0.242288
# 50%        0.284360
# 75%        0.319505
# max        0.429656
# Name: keystone_cluster_FR, dtype: float64
#
# random_FR:
# count    100.000000
# mean       0.298187
# std        0.068138
# min        0.106796
# 25%        0.261380
# 50%        0.302585
# 75%        0.335452
# max        0.435728
# Name: random_FR, dtype: float64
#
# other_species_FR:
# count    100.000000
# mean       0.278247
# std        0.066683
# min        0.089686
# 25%        0.236896
# 50%        0.282437
# 75%        0.335389
# max        0.415047
# Name: other_species_FR, dtype: float64

# %%
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
import pandas as pd

# Load data for different reduction values
seed = 42
reductions = [0.05, 0.1, 0.15, 0.2]

all_results = []

for reduction in reductions:
    df = pd.read_csv(f'simulation_results_root_seed_{seed}_reduction_{reduction}.tsv', sep='\t')
    df['reduction'] = reduction  # Add reduction column
    all_results.append(df)

# Combine all data
combined_results = pd.concat(all_results)

# Prepare data for plotting
fr_columns = ['keystone_species_FR', 'keystone_cluster_FR', 'random_FR', 'other_species_FR']
plot_data = combined_results[fr_columns + ['reduction']].melt(id_vars=['reduction'])

# Set figure size
plt.figure(figsize=(12, 6))

# Create boxplot
sns.boxplot(x='reduction', y='value', hue='variable', data=plot_data)

# Improve labels
plt.xlabel('Reduction')
plt.ylabel('FR Value')
plt.title('FR Values Across Different Reduction Levels')

# Update legend labels
new_labels = ['Keystone Species', 'Keystone Cluster', 'Random', 'Other Species']
handles, _ = plt.gca().get_legend_handles_labels()
plt.legend(handles, new_labels, title='Perturbation Type', bbox_to_anchor=(1.05, 1), loc='upper left')

# Save figure
plt.tight_layout()
plt.savefig(f'FR_boxplot_root_seed_{seed}_all_reductions.png', bbox_inches='tight')
plt.close()

# Statistical analysis for each reduction value
for reduction in reductions:
    results_df = combined_results[combined_results['reduction'] == reduction]
    
    print(f"\n=== Statistical Analysis (Reduction = {reduction}) ===")
    
    # Perform pairwise Mann-Whitney U tests
    perturbation_pairs = []
    for i in range(len(fr_columns)):
        for j in range(i+1, len(fr_columns)):
            stat, p_value = stats.mannwhitneyu(
                results_df[fr_columns[i]], 
                results_df[fr_columns[j]],
                alternative='two-sided'
            )
            perturbation_pairs.append({
                'comparison': f'{fr_columns[i]} vs {fr_columns[j]}',
                'statistic': stat,
                'p_value': p_value
            })
    
    # Create DataFrame for test results
    stats_df = pd.DataFrame(perturbation_pairs)
    
    print(f"\nMann-Whitney U test results:")
    print(stats_df)
    
    print(f"\nBasic statistics:")
    print(results_df[fr_columns].describe())
# Out:
# === Statistical Analysis (Reduction = 0.05) ===
#
# Mann-Whitney U test results:
#                                    comparison  statistic   p_value
# 0  keystone_species_FR vs keystone_cluster_FR     4429.0  0.163245
# 1            keystone_species_FR vs random_FR     4290.0  0.082934
# 2     keystone_species_FR vs other_species_FR     3825.0  0.004101
# 3            keystone_cluster_FR vs random_FR     4726.0  0.503962
# 4     keystone_cluster_FR vs other_species_FR     4287.0  0.081698
# 5               random_FR vs other_species_FR     4494.0  0.216781
#
# Basic statistics:
#        keystone_species_FR  keystone_cluster_FR   random_FR  other_species_FR
# count           100.000000           100.000000  100.000000        100.000000
# mean              0.385652             0.395820    0.400797          0.412171
# std               0.077267             0.076525    0.077546          0.076237
# min               0.218626             0.206447    0.210246          0.225651
# 25%               0.343569             0.354603    0.360470          0.367948
# 50%               0.372044             0.387047    0.391880          0.410232
# 75%               0.437643             0.451350    0.461649          0.473110
# max               0.499041             0.511077    0.524940          0.530875
#
# === Statistical Analysis (Reduction = 0.1) ===
#
# Mann-Whitney U test results:
#                                    comparison  statistic   p_value
# 0  keystone_species_FR vs keystone_cluster_FR     3896.0  0.007003
# 1            keystone_species_FR vs random_FR     3572.0  0.000486
# 2     keystone_species_FR vs other_species_FR     3370.0  0.000068
# 3            keystone_cluster_FR vs random_FR     4609.0  0.340010
# 4     keystone_cluster_FR vs other_species_FR     4134.0  0.034451
# 5               random_FR vs other_species_FR     4541.0  0.262588
#
# Basic statistics:
#        keystone_species_FR  keystone_cluster_FR   random_FR  other_species_FR
# count           100.000000           100.000000  100.000000        100.000000
# mean              0.325067             0.349941    0.360168          0.373360
# std               0.077144             0.071315    0.073518          0.074944
# min               0.168883             0.151647    0.168681          0.188394
# 25%               0.273701             0.312820    0.321633          0.331955
# 50%               0.310782             0.351921    0.358145          0.384562
# 75%               0.395970             0.400394    0.411146          0.421527
# max               0.428212             0.456907    0.491432          0.519230
#
# === Statistical Analysis (Reduction = 0.15) ===
#
# Mann-Whitney U test results:
#                                    comparison  statistic   p_value
# 0  keystone_species_FR vs keystone_cluster_FR     3832.0  0.004330
# 1            keystone_species_FR vs random_FR     3301.0  0.000033
# 2     keystone_species_FR vs other_species_FR     3212.0  0.000013
# 3            keystone_cluster_FR vs random_FR     4373.0  0.125822
# 4     keystone_cluster_FR vs other_species_FR     4642.0  0.382383
# 5               random_FR vs other_species_FR     5330.0  0.420764
#
# Basic statistics:
#        keystone_species_FR  keystone_cluster_FR   random_FR  other_species_FR
# count           100.000000           100.000000  100.000000        100.000000
# mean              0.271465             0.310528    0.326890          0.320581
# std               0.086076             0.070474    0.070063          0.073032
# min               0.118823             0.102033    0.136737          0.136737
# 25%               0.203808             0.270310    0.289649          0.274590
# 50%               0.254591             0.321206    0.329747          0.322936
# 75%               0.352380             0.352916    0.373791          0.383617
# max               0.392209             0.442006    0.462994          0.462082
#
# === Statistical Analysis (Reduction = 0.2) ===
#
# Mann-Whitney U test results:
#                                    comparison  statistic   p_value
# 0  keystone_species_FR vs keystone_cluster_FR     3691.0  0.001386
# 1            keystone_species_FR vs random_FR     3047.0  0.000002
# 2     keystone_species_FR vs other_species_FR     3569.0  0.000473
# 3            keystone_cluster_FR vs random_FR     4143.0  0.036370
# 4     keystone_cluster_FR vs other_species_FR     5053.0  0.897929
# 5               random_FR vs other_species_FR     5875.0  0.032619
#
# Basic statistics:
#        keystone_species_FR  keystone_cluster_FR   random_FR  other_species_FR
# count           100.000000           100.000000  100.000000        100.000000
# mean              0.224947             0.277095    0.298187          0.278247
# std               0.098641             0.071809    0.068138          0.066683
# min               0.068771             0.073984    0.106796          0.089686
# 25%               0.133941             0.242288    0.261380          0.236896
# 50%               0.229433             0.284360    0.302585          0.282437
# 75%               0.314691             0.319505    0.335452          0.335389
# max               0.375875             0.429656    0.435728          0.415047

# %%
import os
import shutil
import glob

output_dir = '../result/perturbation_simulation/'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Move simulation result files
shutil.move("nash_abundance_filtered_threshold_80.tsv", os.path.join(output_dir,"nash_abundance_filtered_threshold_80.tsv"))
shutil.move("simulation_params_root_seed_42.tsv", os.path.join(output_dir,"simulation_params_root_seed_42.tsv"))
shutil.move("FR_boxplot_root_seed_42_all_reductions.png", os.path.join(output_dir,"FR_boxplot_root_seed_42_all_reductions.png"))

for file in glob.glob('simulation_results_root_seed_42*.tsv'):
    shutil.move(file, os.path.join(output_dir,file))
