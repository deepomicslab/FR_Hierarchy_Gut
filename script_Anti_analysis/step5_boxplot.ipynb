# %%
# this is the pipeline of phenotype analysis
import sys
sys.path.append('..')
import os
import pandas as pd
import copy
import pandas as pd
import numpy as np
from scipy.stats import mannwhitneyu
import matplotlib.pyplot as plt
import tree_util
import seaborn as sns
from statsmodels.stats.multitest import fdrcorrection as fdr

# %%
def nfr(d_df, profile, sname):
    sp_list = list(profile.columns)
    n = len(sp_list)
    corr = np.ones(shape=(n, n)) - d_df.loc[sp_list, sp_list].values
    np.fill_diagonal(corr, 0)
    # print(corr[1, 1])
    a = np.array(profile.loc[sname, sp_list])
    inter_matrix = np.dot(a.reshape(len(a), 1),a.reshape(1, len(a)))
    np.fill_diagonal(inter_matrix, 0)
    td = np.sum(inter_matrix)/2
    fr = np.sum(np.multiply(inter_matrix, corr))/2
    fd = np.sum(np.multiply(inter_matrix, d_df.loc[sp_list, sp_list].values))/2
    if td == 0:
        return 0
    return fr/td

def multisample_nfr(profile, d_df, node_leaves):
    result = pd.DataFrame(index=profile.index, columns=(list(node_leaves.keys()) + ['nroot']))
    for sname in profile.index:
       for node, sp_list in node_leaves.items():
           sp_list = list(set(sp_list).intersection(set(profile.columns)))
           selected_d = d_df.loc[sp_list, sp_list]
           selected_profile = profile.loc[:, sp_list]
           value = nfr(selected_d, selected_profile, sname)
           result.loc[sname, node] = value
    if 'nroot' in result.columns:
        result.drop('nroot', axis=1, inplace=True)
    return result

# %%
#outdir = '../result/Anti/nFR'
##if not os.path.exists(outdir):
#   os.makedirs(outdir)
with open('../result/GCN_fix_tree/renamed_GCN_tree.newick') as fp:
    newick_tree = fp.read()

json_tree = tree_util.parse(newick_tree)
largest = {'largest': 0}
leaf_list, l = tree_util.recu_compute(json_tree, 0, largest)
largest_level = largest['largest']
nlayer = largest_level
layer_leaves_dict = tree_util.make_layer_dict(nlayer)
tree_util.recu_layer(json_tree, layer_leaves_dict)
tree_util.to_layer_leaves(layer_leaves_dict, nlayer)
leaves_dict = copy.deepcopy(layer_leaves_dict)
parent_dict = {}
tree_util.parents(json_tree, parent_dict)
node_leaves = {}
for level in layer_leaves_dict.keys():
    for node, sp_list in layer_leaves_dict[level].items():
        if node in node_leaves.keys():
            continue
        node_leaves[node] = copy.deepcopy(sp_list)
subtree_nodes = {}
for l in leaf_list:
    parent = parent_dict[l]
    if parent not in subtree_nodes.keys():
        subtree_nodes[parent] = []
    subtree_nodes[parent].append(l)

for node in node_leaves.keys():
    parent = parent_dict[node]
    if parent not in subtree_nodes.keys():
        subtree_nodes[parent] = []
    subtree_nodes[parent] += subtree_nodes[node]
    subtree_nodes[parent].append(node)

node_leaves['root'] = list(leaf_list)

for node in subtree_nodes.keys():
    subtree_nodes[node].append(node)

direct_children_dict = {}
for node, parent in parent_dict.items():
    if parent not in direct_children_dict:
        direct_children_dict[parent] = []
    direct_children_dict[parent].append(node)

# %%
d_df = pd.read_csv('../data/sp_d.tsv', sep='\t', header=0, index_col=0)
metadata = pd.read_csv('../data/Anti/metadata.csv', sep=',', index_col=None, header=0)
abd = pd.read_csv('../data/Anti/abd.tsv', sep='\t', header=0, index_col=0)

# %%
metadata = metadata[['Sample_Name', 'Timepoint', 'type']]
metadata = metadata.drop_duplicates(inplace=False)
sname_tmp = 'P{}E{}'
abd_name_dict = {}
for idx in abd.index:
    abd_name_dict[idx] = idx.split('|')[-1].replace('_', '-')
abd = abd.rename(index=abd_name_dict) 
name_dict = {}
for sp in d_df.columns:
        name_dict[sp] = sp.replace('_', '-')
d_df = d_df.rename(columns=name_dict, index=name_dict)
print(abd.loc[sp_list, ].sum(axis=0)[['P22E90', 'P25C7', 'P25C90']])
abd = abd.T/100
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-f1804e3bb5b4> in <module>
#      10         name_dict[sp] = sp.replace('_', '-')
#      11 d_df = d_df.rename(columns=name_dict, index=name_dict)
# ---> 12 print(abd.loc[sp_list, ].sum(axis=0)[['P22E90', 'P25C7', 'P25C90']])
#      13 abd = abd.T/100
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1066             if self._is_scalar_access(key):
#    1067                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1068             return self._getitem_tuple(key)
#    1069         else:
#    1070             # we by definition only have the 0th axis
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1253         # ugly hack for GH #836
#    1254         if self._multi_take_opportunity(tup):
# -> 1255             return self._multi_take(tup)
#    1256
#    1257         return self._getitem_tuple_same_dim(tup)
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py in _multi_take(self, tup)
#    1204         """
#    1205         # GH 836
# -> 1206         d = {
#    1207             axis: self._get_listlike_indexer(key, axis)
#    1208             for (key, axis) in zip(tup, self.obj._AXIS_ORDERS)
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py in <dictcomp>(.0)
#    1205         # GH 836
#    1206         d = {
# -> 1207             axis: self._get_listlike_indexer(key, axis)
#    1208             for (key, axis) in zip(tup, self.obj._AXIS_ORDERS)
#    1209         }
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1431         axis_name = self.obj._get_axis_name(axis)
#    1432
# -> 1433         keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1434
#    1435         return keyarr, indexer
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    6106             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6107
# -> 6108         self._raise_if_missing(keyarr, indexer, axis_name)
#    6109
#    6110         keyarr = self.take(indexer)
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexes\base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6166                 if use_interval_msg:
#    6167                     key = list(key)
# -> 6168                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6169
#    6170             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['s--Duganella-phyllosphaerae', 's--Duganella-sp-Leaf126',\n       's--Duganella-sp-Leaf61', 's--Janthinobacterium-lividum',\n       's--Janthinobacterium-sp-64', 's--Janthinobacterium-sp-AD80',\n       's--Janthinobacterium-sp-S3-2', 's--Janthinobacterium-sp-TND4EL3',\n       's--Massilia-oculi', 's--Massilia-sp-LC238', 's--Massilia-timonae'],\n      dtype='object')] are in the [index]"

# %%
#sp_list = list(set(sp_list).intersection(set(abd.columns)))
#selected = abd[['P22E90', 'P25C7', 'P25C90']]

#selected = selected.T/100
#selected = selected[list(set(selected.columns).intersection(set(d_df.columns)))]
#selected
set(node_leaves['cluster_S1-C4']).intersection(set(abd.loc[['P22E90', 'P25C7', 'P25C90'], :].columns))
# Out:
# {'s--Abiotrophia-sp-HMSC24B09',
#  's--Enterococcus-faecium',
#  's--Gemella-morbillorum',
#  's--Gemella-sanguinis',
#  's--Lactococcus-lactis'}

# %%
abd.loc[['P22E90', 'P25C7', 'P25C90'], sp_list]
sp_list2 = 's--Gemella-sanguinis' , 's--Lactococcus-lactis'
new = abd.loc[['P22E90', 'P25C7', 'P25C90'], sp_list2]

# %%
selected_d = d_df.loc[sp_list2, sp_list2]
corr = np.ones(shape=(2, 2)) - selected_d.loc[sp_list2, sp_list2].values
corr
# Out:
# array([[1.        , 0.42169657],
#        [0.42169657, 1.        ]])

# %%
for s in selected_d.index:
    fr = selected_d.loc[s, sp_list2[0]]* selected_d.loc[s, sp_list2[0]] *

# %%
selected_l = node_leaves['cluster_S1-C4']
# selected = selected.loc[list(set(selected_l).intersection(set(selected.columns))), :]

# %%
sp_list = selected_l
profile = abd
sp_list = list(set(sp_list).intersection(set(profile.columns)))
selected_d = d_df.loc[sp_list, sp_list]
selected_profile = profile.loc[:, sp_list]
sname = 'P25C7'
value = nfr(selected_d, selected_profile, sname)
value
# Out:
# 0.4216965742251224

# %%
sp_list = list(selected_profile.columns)
n = len(sp_list)
corr = np.ones(shape=(n, n)) - selected_d.loc[sp_list, sp_list].values
np.fill_diagonal(corr, 0)
# print(corr[1, 1])
a = np.array(profile.loc[sname, sp_list])
inter_matrix = np.dot(a.reshape(len(a), 1),a.reshape(1, len(a)))
np.fill_diagonal(inter_matrix, 0)
td = np.sum(inter_matrix)/2
fr = np.sum(np.multiply(inter_matrix, corr))/2
fd = np.sum(np.multiply(inter_matrix, d_df.loc[sp_list, sp_list].values))/2
print(td,fr)
fr/td

# %%
a = abd.loc['P25C7', sp_list]
corr = np.ones(shape=(n, n)) - selected_d.loc[sp_list, sp_list].values
np.fill_diagonal(corr, 0)
# print(corr[1, 1])
a = np.array(profile.loc[sname, sp_list])
inter_matrix = np.dot(a.reshape(len(a), 1),a.reshape(1, len(a)))
np.fill_diagonal(inter_matrix, 0)
td = np.sum(inter_matrix)/2
fr = np.sum(np.multiply(inter_matrix, corr))/2
fd = np.sum(np.multiply(inter_matrix, d_df.loc[sp_list, sp_list].values))/2
print(a, np.sum(a), td, fr, fr/td)
fr/td
# Out:
# [0.0e+00 9.3e-06 0.0e+00 0.0e+00 4.4e-06] 1.3700000000000001e-05 4.0920000000000006e-11 1.725582381729201e-11 0.4216965742251224
# 0.4216965742251224

# %%
a = abd.loc['P22E90', sp_list]
print(a)
a = np.array(a)
print(a)
corr = np.ones(shape=(n, n)) - selected_d.loc[sp_list, sp_list].values
np.fill_diagonal(corr, 0)
# print(corr[1, 1])
inter_matrix = np.dot(a.reshape(len(a), 1),a.reshape(1, len(a)))
np.fill_diagonal(inter_matrix, 0)
td = np.sum(inter_matrix)/2
fr = np.sum(np.multiply(inter_matrix, corr))/2
fd = np.sum(np.multiply(inter_matrix, d_df.loc[sp_list, sp_list].values))/2
print(np.sum(a), td, fr, fr/td)
# Out:
# s--Enterococcus-faecium        0.000000
# s--Gemella-sanguinis           0.000034
# s--Abiotrophia-sp-HMSC24B09    0.000000
# s--Gemella-morbillorum         0.000000
# s--Lactococcus-lactis          0.000002
# Name: P22E90, dtype: float64
# [0.00e+00 3.42e-05 0.00e+00 0.00e+00 2.00e-06]
# 3.62e-05 6.839999999999999e-11 2.884404567699837e-11 0.4216965742251224

# %%
a = abd.loc['P25C90', sp_list]
print(a)
a = np.array(a)
print(a)
corr = np.ones(shape=(n, n)) - selected_d.loc[sp_list, sp_list].values
np.fill_diagonal(corr, 0)
# print(corr[1, 1])
inter_matrix = np.dot(a.reshape(len(a), 1),a.reshape(1, len(a)))
np.fill_diagonal(inter_matrix, 0)
td = np.sum(inter_matrix)/2
fr = np.sum(np.multiply(inter_matrix, corr))/2
fd = np.sum(np.multiply(inter_matrix, d_df.loc[sp_list, sp_list].values))/2
print(np.sum(a), td, fr, fr/td)
# Out:
# s--Enterococcus-faecium        0.000000
# s--Gemella-sanguinis           0.000006
# s--Abiotrophia-sp-HMSC24B09    0.000000
# s--Gemella-morbillorum         0.000000
# s--Lactococcus-lactis          0.000407
# Name: P25C90, dtype: float64
# [0.000e+00 5.700e-06 0.000e+00 0.000e+00 4.067e-04]
# 0.00041239999999999994 2.31819e-09 9.775727814029365e-10
# 0.42169657422512247

# %%
name_dict = {}
for sp in d_df.columns:
        name_dict[sp] = sp.replace('_', '-')
d_df = d_df.rename(columns=name_dict, index=name_dict)
abd = abd.T/100
sub_ids = sorted(list(set(metadata['Sample_Name'])))
days = sorted(list(set(metadata['Timepoint'])))
phenos = list(set(metadata['type']))
profile = abd[list(set(abd.columns).intersection(set(d_df.columns)))]
se_result = multisample_nfr(profile, d_df, node_leaves)
se_result.to_csv(os.path.join(outdir, 'nfr_df.tsv'), sep='\t')

# %%
p_cutoff = 0.05
if not os.path.exists(outdir):
    os.makedirs(outdir)

p1 = phenos[1]
p0 = phenos[0]
# compute p-value with fdr
p_df = pd.DataFrame(columns=days, index=list(node_leaves.keys()))
valid_dict = {}
for k in node_leaves.keys():
    metadata[k] = list(se_result.loc[list(metadata['Sample_Name']), k] )
    for j in days:
        selected0 = list(metadata[(metadata['Timepoint'] == j) & (metadata['type'] == p0)]['Sample_Name'])
        selected1 = list(metadata[(metadata['Timepoint'] == j) & (metadata['type'] == p1)]['Sample_Name'])
        selected_v0 = se_result.loc[selected0, k]
        selected_v1 = se_result.loc[selected1, k]
        if (list(selected_v0).count(0) > len(list(selected_v0))*0.8) and (list(selected_v1).count(0) > len(list(selected_v1))*0.8):
            continue
        if j not in valid_dict.keys():
            valid_dict[j] = []
        valid_dict[j].append(k)
        t, p = mannwhitneyu(list(selected_v0), list(selected_v1))
        p_df.loc[k, j] = p
        
p_df_adj = pd.DataFrame(columns=p_df.columns, index=list(node_leaves.keys()))
for d in days:
    p_values = p_df.loc[valid_dict[d], d]
    p_adj = fdr(p_values, p_cutoff)[1]
    for i, cluster in enumerate(valid_dict[d]):
        p_df_adj.loc[cluster, d] = p_adj[i]
p_df_adj.fillna(np.nan, inplace=True)
p_df_adj.to_csv(os.path.join(outdir, 'p_value.tsv'), sep='\t')

# %%
# draw
for k in node_leaves.keys():
    metadata[k] = list(se_result.loc[list(metadata['Sample_Name']), k] )
    max_v = max(list(metadata[k]))
    show = False
    for j in days:
        if k in valid_dict[j]:
            show = True
    if not show:
        continue
    sns.boxplot(x='Timepoint', y=k, hue='type', data=metadata)
    for i, t in enumerate(days):
        if pd.isna(p_df_adj.loc[k, t]):
            plt.text(i, max_v*1.2, 'X', ha='center', va='bottom', fontsize=20, color='black')

        if p_df_adj.loc[k, t] < p_cutoff:
            plt.text(i, max_v*1.2, '**', ha='center', va='bottom', fontsize=20, color='r')
    plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
    plt.ylim(-0.1*max_v, max_v*1.5)
    plt.title(k)
    #plt.show()
    plt.tight_layout()
    plt.savefig(os.path.join(outdir, '{}.pdf'.format(k)), dpi=300, format='pdf')
    plt.show()
